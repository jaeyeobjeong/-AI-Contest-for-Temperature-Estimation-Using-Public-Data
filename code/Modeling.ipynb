# %%
import lightgbm as lgb
from sklearn.model_selection import train_test_split

import pandas as pd
import numpy as np
import os

import warnings
warnings.filterwarnings(action='ignore')

path = '/Users/jaeyeobjeong/Desktop/포트폴리오/프로젝트/온도 예측/data'

train = pd.read_csv(f'{path}/train.csv')
y_train = np.log1p(train['Y18'])

data = pd.read_csv(f'{path}/for_modeling_data.csv')

# %%
def lgbm_regressor(train_X, train_y, test_X, test_y, feature_names=None, seed_val=2284, num_rounds=18703):
    param = {
        'boosting' : 'dart',
        'objective' : 'regression',
        'learning_rate' : 0.05,
        'max_depth' : 10,
        'metric' : 'rmse',
        'is_training_metric' : True,
        'min_child_weight' : 1,
        'bagging_fraction' : 0.8,
        'num_leaves' : 128,
        'feaure_fraction' : 0.8,
        'bagging_freq' : 6,
        'seed' : seed_val,
        'min_split_gain' : 0.01,   
    }
    
    plst = list(param.items())

    train_ds = lgb.Dataset(train_X, label=train_y)
    test_ds = lgb.Dataset(test_X, label=test_y)

    model = lgb.train(param, train_ds, num_rounds,test_ds, early_stopping_rounds=180)

    return model

# %%
common_columns =[
    'temper_1', 'land_pressure_1', 'wind_1', 'wind_2', 'rain_1', 'sea_pressure_1', 'land_pressure_2', 'temper_2',
    'sea_pressure_2', 'sea_pressure_3', 'rain_2', 'sunshine_1', 'humidity_1', 'wind_direction_1', 'sunshine_2', 'wind_direction_2',
    'sunshine_3', 'wind_direction_3', 'wind_3', 'sunshine_4', 'humidity_2', 'rain_3', 'land_pressure_3', 'sea_pressure_4',
    'wind_4', 'wind_direction_4', 'wind_5', 'land_pressure_4', 'temper_3', 'land_pressure_5', 'humidity_3', 'temper_4',
    'temper_5', 'sea_pressure_5', 'sunshine_5', 'wind_direction_5', 'rain_4', 'humidity_4', 'humidity_5', 'rain_5', 'min'
]

# %%
COL1 = common_columns + [

 'diff_humidity_1_2', 'diff_humidity_1_5', 'diff_humidity_6_3', 'diff_humidity_6_4', 'diff_humidity_6_5',
 'diff_humidity36_humidity_3','diff_humidity72_humidity_2', 'diff_humidity144_humidity_1', 'diff_humidity216_humidity_2',
 
 'rain',  
 'time_rain_sum',

 'time_cat_t3',
 'time_cat_t5',
 'time_cat_t6',
    
 'sunshine_humidity',
    
 'diff_sunshine_1_5',
 'diff_sunshine_1_4',
 'diff_sunshine_1_3',
 'diff_sunshine_1_2',
    
 'diff3_temper_1','diff3_temper_2','diff3_temper_3','diff3_temper_4','diff3_temper_5',
 'diff_1dtemper_2', 'diff_1dtemper_4','diff_1dtemper_5',
 'diff2_5min_temper_5',
 'diff2_5min_temper_3'
]

# %%
COL2 = common_columns + [
    
 'time_cat_std','time_cat_t9',

 'diff_humidity_1_1', 'diff_humidity_1_3', 'diff_humidity_1_4', 'humidity_mean',
 'diff_humidity36_humidity_1', 'diff_humidity144_humidity_2',

 'time_rain_mean', 'time_rain_std',
 
 'diff_sunshine_1_1', 'diff_sunshine_6_1', 'diff_sunshine_6_2', 'diff_sunshine_6_3', 'sunshine_mean'
 
 'diff3_temper_1','diff3_temper_2','diff3_temper_3','diff3_temper_4','diff3_temper_5',
 'diff_1dtemper_5', 'diff_1dtemper_4','diff_1dtemper_2',
 'diff2_temper_1','diff2_temper_4',
 'diff_1dtemper_3', 'diff2_5min_temper_1', 'diff2_5min_temper_2','diff2_5min_temper_4',
]

# %%
COL3 = common_columns + [
    
 'diff2_temper_2', 'diff2_temper_3', 'diff2_temper_5','diff_1dtemper_1',
 'diff3_temper_1','diff3_temper_2','diff3_temper_3','diff3_temper_4','diff3_temper_5',
 'diff_1dtemper_5', 'diff_1dtemper_4','diff_1dtemper_2',
 
 'time_cat_t1','time_cat_t2', 'time_cat_t4', 'time_cat_t7', 'time_cat_t8',
 'time_cat_mean', 'time_cat_sum',
    
 'diff_humidity_6_1', 'diff_humidity_6_2',
 'diff_humidity36_humidity_2', 'diff_humidity72_humidity_1', 'diff_humidity72_humidity_3',
 'diff_humidity144_humidity_3', 'diff_humidity216_humidity_1', 'diff_humidity216_humidity_3',
    
 'diff_sunshine_6_4',    
 'diff_sunshine_6_5'
 ]

# %%
COL4= common_columns + [
    'time_cat_sum', 'time_cat_mean', 'time_cat_std', 'rain', 'time_rain_sum', 'time_rain_mean', 'time_rain_std',
        
    'time_cat_t1', 'time_cat_t2', 'time_cat_t3', 'time_cat_t4',
    'time_cat_t5', 'time_cat_t6', 'time_cat_t7', 'time_cat_t8', 'time_cat_t9', 

    'diff_1dtemper_1', 'diff_1dtemper_2', 'diff_1dtemper_3','diff_1dtemper_4', 'diff_1dtemper_5', 
    'diff2_temper_1', 'diff2_temper_2', 'diff2_temper_3','diff2_temper_4', 'diff2_temper_5', 
    'diff3_temper_1', 'diff3_temper_2', 'diff3_temper_3','diff3_temper_4', 'diff3_temper_5', 
    'diff2_5min_temper_1', 'diff2_5min_temper_2', 'diff2_5min_temper_3', 'diff2_5min_temper_4', 'diff2_5min_temper_5',

    'diff_humidity_1_1', 'diff_humidity_1_2', 'diff_humidity_1_3', 'diff_humidity_1_4', 'diff_humidity_1_5', 
    'diff_humidity_6_1', 'diff_humidity_6_2', 'diff_humidity_6_3', 'diff_humidity_6_4', 'diff_humidity_6_5', 
    'humidity_mean',

    'diff_sunshine_1_1', 'diff_sunshine_1_2', 'diff_sunshine_1_3', 'diff_sunshine_1_4', 'diff_sunshine_1_5',
    'diff_sunshine_6_1', 'diff_sunshine_6_2', 'diff_sunshine_6_3', 'diff_sunshine_6_4', 'diff_sunshine_6_5', 
    'sunshine_mean', 'sunshine_humidity']

# %%
COL5 = common_columns + [
   'time_cat_sum', 'time_cat_mean', 'time_cat_std', 'rain', 'time_rain_sum', 'time_rain_mean', 'time_rain_std', 
    
   'time_cat_t1', 'time_cat_t2', 'time_cat_t3', 'time_cat_t4', 
   'time_cat_t5', 'time_cat_t6', 'time_cat_t7', 'time_cat_t8', 'time_cat_t9',

   'diff_36_temper_1', 'diff_72_temper_1', 'diff_144_temper_1', 'diff_216_temper_1',
   'diff_36_temper_2', 'diff_72_temper_2', 'diff_144_temper_2', 'diff_216_temper_2',
   'diff_36_temper_3', 'diff_72_temper_3', 'diff_144_temper_3', 'diff_216_temper_3',
   'diff_36_temper_4', 'diff_72_temper_4', 'diff_144_temper_4', 'diff_216_temper_4',
   'diff_36_temper_5', 'diff_72_temper_5', 'diff_144_temper_5', 'diff_216_temper_5',

   'diff_humidity_1_1', 'diff_humidity_1_2', 'diff_humidity_1_3', 'diff_humidity_1_4', 'diff_humidity_1_5', 
   'diff_humidity_6_1', 'diff_humidity_6_2', 'diff_humidity_6_3', 'diff_humidity_6_4', 'diff_humidity_6_5', 
   'humidity_mean',

   'diff_sunshine_1_1', 'diff_sunshine_1_2','diff_sunshine_1_3', 'diff_sunshine_1_4', 'diff_sunshine_1_5', 
   'diff_sunshine_6_1', 'diff_sunshine_6_2', 'diff_sunshine_6_3', 'diff_sunshine_6_4', 'diff_sunshine_6_5',
   'sunshine_mean', 'sunshine_humidity']

# %%
for i, COL in enumerate([COL1, COL2, COL3, COL4, COL5]):
    X_train = data[COL].iloc[:train.shape[0],:]
    X_test = data[COL].iloc[train.shape[0]:,:]

    train_x, train_cv, y, y_cv = train_test_split(X_train,y_train, test_size=0.15, random_state=1217)
    model = lgbm_regressor(train_X = train_x, train_y = y, test_X = train_cv, test_y = y_cv)

    y_test =  np.exp(model.predict(X_test))

    submission['Y18'] = y_test
    if i < 3 : 
        submission.to_csv(f'{path}/Ensemble/{COL}_test.csv',index=False)
    else:
        submission.to_csv(f'{path}/{COL}_test.csv',index=False)
# Out:
# /Users/jaeyeobjeong/.pyenv/versions/3.9.9/lib/python3.9/site-packages/lightgbm/engine.py:181: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /Users/jaeyeobjeong/.pyenv/versions/3.9.9/lib/python3.9/site-packages/lightgbm/callback.py:223: UserWarning: Early stopping is not available in dart mode
#   _log_warning('Early stopping is not available in dart mode')
# [LightGBM] [Warning] Unknown parameter: feaure_fraction
# [LightGBM] [Warning] Unknown parameter: feaure_fraction
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002057 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 10804
# ...

# %%
folder = f'{path}/Ensemble'
nf = 0
for Q in os.listdir(folder):
    ext = os.path.splitext(Q)[-1]
    s = pd.read_csv(folder+"/"+Q)
    
    if nf == 0: 
        slist = s
    else: 
        slist = pd.merge(slist, s, on="id")
    nf += 1

p = 88.4

pred_m = 0
for J in range(nf): 
    pred_m += slist.iloc[:,J+1]**p 
pred_m = pred_m / nf    
pred_m = pred_m**(1/p)

cols_ensemble = pd.DataFrame({'id': slist.id, 'Y18': pred_m}).fillna(0)['Y18']

# %%
col4_pred = pd.read_csv(f'{path}/COL4_test.csv')['Y18']
col5_pred = pd.read_csv(f'{path}/COL5_test.csv')['Y18']

# %%
w1 = 0.5
w2 = 0.1
w3 = 0.4

pd.DataFrame({'id': slist.id, 'Y18': (w1*cols_ensemble+w2*col4_pred+w3*col5_pred)}) \
.to_csv(f'{path}/submission_.csv',index=False)
